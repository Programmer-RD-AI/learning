# %%
import torch

# %%
X = torch.randn(3,requires_grad=True)

# %%
X
# Out:
# tensor([ 0.3891, -0.2005, -0.2464], requires_grad=True)

# %%
y = X + 2

# %%
y
# Out:
# tensor([2.3891, 1.7995, 1.7536], grad_fn=<AddBackward0>)

# %%
z = y*y*2

# %%
z
# Out:
# tensor([11.4156,  6.4761,  6.1502], grad_fn=<MulBackward0>)

# %%
v = torch.tensor([0.1,1.0,0.001],dtype=torch.float32)

# %%
z.backward(v)

# %%
X.grad
# Out:
# tensor([9.5564e-01, 7.1978e+00, 7.0144e-03])

# %%
z
# Out:
# tensor([11.4156,  6.4761,  6.1502], grad_fn=<MulBackward0>)

# %%
X = torch.randn(3,requires_grad=True)

# %%
X
# Out:
# tensor([ 0.3316, -2.1486,  0.0645], requires_grad=True)

# %%
X.requires_grad_(False)
# Out:
# tensor([ 0.3316, -2.1486,  0.0645])

# %%
X.detach()
# Out:
# tensor([ 0.3316, -2.1486,  0.0645])

# %%
with torch.no_grad():
    print(X)
# Out:
# tensor([ 0.3316, -2.1486,  0.0645])

# %%
weights = torch.ones(4,requires_grad=True)
for epoch in range(3):
    model_output = (weights*3).sum()
    print(model_output)
    model_output.backward()
    print(weights.grad)
    weights.grad.zero_()
# Out:
# tensor(12., grad_fn=<SumBackward0>)
# tensor([3., 3., 3., 3.])
# tensor(12., grad_fn=<SumBackward0>)
# tensor([3., 3., 3., 3.])
# tensor(12., grad_fn=<SumBackward0>)
# tensor([3., 3., 3., 3.])

# %%
weights.grad.zero_()
# Out:
# tensor([0., 0., 0., 0.])

# %%
weights
# Out:
# tensor([1., 1., 1., 1.], requires_grad=True)

# %%
import torch

# %%
x = torch.tensor(1.0)

# %%
y = torch.tensor(2.0)

# %%
w = torch.tensor(1.0,requires_grad=True)

# %%
y_hat = w * x
loss = (y_hat - y)**2

# %%
loss
# Out:
# tensor(1., grad_fn=<PowBackward0>)

# %%
loss.backward(retain_graph=False)

# %%
w.grad
# Out:
# tensor(-2.)

# %%
import numpy as np

# %%
# f = w * x
# f = 2 * x
X = np.array([1,2,3,4],dtype=np.float32)

# %%
Y = np.array([1*2,2*2,3*2,4*2],dtype=np.float32)

# %%
w = 0.0

# %%
# model preds
def forward(x):
    return w * x

# %%
# loss = MSE
def loss(y,y_preds):
    return ((y_preds-y)**2).mean()

# %%
# gradient
# MSE = 1/N * (w * x - y)**2
def gradient(x,y,y_preds):
    return np.dot(2*x,y_preds-y).mean()

# %%
print(f'Preds before Training : f(5) = {forward(5):.3f}')
# Out:
# Preds before Training : f(5) = 0.000

# %%
learning_rate = 0.01
n_iters = 2500

# %%
for epoch in range(n_iters):
    # preds = forward pass
    y_preds = forward(X)
    # loss
    l = loss(Y,y_preds)
    # gradients
    dw = gradient(X,Y,y_preds)
    # update weights
    w -= learning_rate * dw
    print(dw)
    print(f'Epoch : {epoch+1} Weight : {w:.3f} Loss = {l:.8f}')
# Out:
# -120.0
# Epoch : 1 Weight : 1.200 Loss = 30.00000000
# -47.999996
# Epoch : 2 Weight : 1.680 Loss = 4.79999924
# -19.200003
# Epoch : 3 Weight : 1.872 Loss = 0.76800019
# -7.68
# Epoch : 4 Weight : 1.949 Loss = 0.12288000
# -3.0720026
# Epoch : 5 Weight : 1.980 Loss = 0.01966083
# -1.2288015
# Epoch : 6 Weight : 1.992 Loss = 0.00314574
# -0.49151587
# Epoch : 7 Weight : 1.997 Loss = 0.00050331
# -0.1966095
# Epoch : 8 Weight : 1.999 Loss = 0.00008053
# -0.07864165
# Epoch : 9 Weight : 1.999 Loss = 0.00001288
# -0.031455517
# Epoch : 10 Weight : 2.000 Loss = 0.00000206
# -0.012580633
# Epoch : 11 Weight : 2.000 Loss = 0.00000033
# -0.0050354004
# Epoch : 12 Weight : 2.000 Loss = 0.00000005
# -0.0020184517
# Epoch : 13 Weight : 2.000 Loss = 0.00000001
# -0.0008010864
# Epoch : 14 Weight : 2.000 Loss = 0.00000000
# -0.00032258034
# Epoch : 15 Weight : 2.000 Loss = 0.00000000
# -0.00013017654
# Epoch : 16 Weight : 2.000 Loss = 0.00000000
# -4.9352646e-05
# Epoch : 17 Weight : 2.000 Loss = 0.00000000
# -2.0742416e-05
# Epoch : 18 Weight : 2.000 Loss = 0.00000000
# -7.867813e-06
# Epoch : 19 Weight : 2.000 Loss = 0.00000000
# -7.867813e-06
# Epoch : 20 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 21 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 22 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 23 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 24 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 25 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 26 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 27 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 28 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 29 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 30 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 31 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 32 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 33 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 34 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 35 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 36 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 37 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 38 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 39 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 40 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 41 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 42 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 43 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 44 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 45 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 46 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 47 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 48 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 49 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 50 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 51 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 52 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 53 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 54 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 55 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 56 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 57 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 58 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 59 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 60 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 61 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 62 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 63 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 64 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 65 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 66 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 67 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 68 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 69 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 70 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 71 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 72 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 73 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 74 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 75 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 76 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 77 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 78 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 79 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 80 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 81 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 82 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 83 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 84 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 85 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 86 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 87 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 88 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 89 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 90 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 91 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 92 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 93 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 94 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 95 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 96 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 97 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 98 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 99 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 100 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 101 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 102 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 103 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 104 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 105 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 106 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 107 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 108 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 109 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 110 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 111 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 112 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 113 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 114 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 115 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 116 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 117 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 118 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 119 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 120 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 121 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 122 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 123 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 124 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 125 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 126 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 127 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 128 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 129 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 130 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 131 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 132 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 133 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 134 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 135 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 136 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 137 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 138 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 139 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 140 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 141 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 142 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 143 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 144 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 145 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 146 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 147 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 148 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 149 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 150 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 151 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 152 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 153 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 154 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 155 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 156 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 157 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 158 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 159 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 160 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 161 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 162 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 163 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 164 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 165 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 166 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 167 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 168 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 169 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 170 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 171 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 172 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 173 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 174 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 175 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 176 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 177 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 178 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 179 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 180 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 181 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 182 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 183 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 184 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 185 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 186 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 187 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 188 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 189 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 190 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 191 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 192 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 193 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 194 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 195 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 196 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 197 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 198 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 199 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 200 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 201 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 202 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 203 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 204 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 205 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 206 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 207 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 208 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 209 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 210 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 211 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 212 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 213 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 214 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 215 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 216 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 217 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 218 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 219 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch :
Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 2499 Weight : 2.000 Loss = 0.00000000
# 0.0
# Epoch : 2500 Weight : 2.000 Loss = 0.00000000

# %%
print(f'Preds before Training : f(5) = {forward(5):.3f}')
# Out:
# Preds before Training : f(5) = 10.000

# %%
import torch
# Compute every step manually

# Linear regression
# f = w * x 

# here : f = 2 * x
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

w = torch.tensor(0.0,dtype=torch.float32,requires_grad=True)

# model output
def forward(x):
    return w * x

# loss = MSE
def loss(y, y_pred):
    return ((y_pred - y)**2).mean()

print(f'Prediction before training: f(5) = {forward(5):.3f}')

# Training
learning_rate = 0.01
n_iters = 75

for epoch in range(n_iters):
    # predict = forward pass
    y_pred = forward(X)

    # loss
    l = loss(Y, y_pred)
    
    # calculate gradients
    l.backward()

    # update weights
    with torch.no_grad():
        w -= learning_rate * w.grad
    w.grad.zero_()
    if epoch % 2 == 0:
        print(f'epoch {epoch+1}: w = {w:.3f}, loss = {l:.8f}')
     
print(f'Prediction after training: f(5) = {forward(5):.3f}')
# Out:
# Prediction before training: f(5) = 0.000
# epoch 1: w = 0.300, loss = 30.00000000
# epoch 3: w = 0.772, loss = 15.66018772
# epoch 5: w = 1.113, loss = 8.17471695
# epoch 7: w = 1.359, loss = 4.26725292
# epoch 9: w = 1.537, loss = 2.22753215
# epoch 11: w = 1.665, loss = 1.16278565
# epoch 13: w = 1.758, loss = 0.60698116
# epoch 15: w = 1.825, loss = 0.31684780
# epoch 17: w = 1.874, loss = 0.16539653
# epoch 19: w = 1.909, loss = 0.08633806
# epoch 21: w = 1.934, loss = 0.04506890
# epoch 23: w = 1.952, loss = 0.02352631
# epoch 25: w = 1.966, loss = 0.01228084
# epoch 27: w = 1.975, loss = 0.00641066
# epoch 29: w = 1.982, loss = 0.00334642
# epoch 31: w = 1.987, loss = 0.00174685
# epoch 33: w = 1.991, loss = 0.00091188
# epoch 35: w = 1.993, loss = 0.00047601
# epoch 37: w = 1.995, loss = 0.00024848
# epoch 39: w = 1.996, loss = 0.00012971
# epoch 41: w = 1.997, loss = 0.00006770
# epoch 43: w = 1.998, loss = 0.00003534
# epoch 45: w = 1.999, loss = 0.00001845
# epoch 47: w = 1.999, loss = 0.00000963
# epoch 49: w = 1.999, loss = 0.00000503
# epoch 51: w = 1.999, loss = 0.00000262
# epoch 53: w = 2.000, loss = 0.00000137
# epoch 55: w = 2.000, loss = 0.00000071
# epoch 57: w = 2.000, loss = 0.00000037
# epoch 59: w = 2.000, loss = 0.00000019
# epoch 61: w = 2.000, loss = 0.00000010
# epoch 63: w = 2.000, loss = 0.00000005
# epoch 65: w = 2.000, loss = 0.00000003
# epoch 67: w = 2.000, loss = 0.00000001
# epoch 69: w = 2.000, loss = 0.00000001
# epoch 71: w = 2.000, loss = 0.00000000
# epoch 73: w = 2.000, loss = 0.00000000
# epoch 75: w = 2.000, loss = 0.00000000
# Prediction after training: f(5) = 10.000

# %%
import torch
import torch.nn as nn
# Here we replace the manually computed gradient with autograd

# Linear regression
# f = w * x 

# here : f = 2 * x
X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8], dtype=torch.float32)

w = torch.tensor(0.0, dtype=torch.float32, requires_grad=True)

# model output
def forward(x):
    return w * x

print(f'Prediction before training: f(5) = {forward(5).item():.3f}')

# Training
learning_rate = 0.01
n_iters = 100
loss = nn.MSELoss()
optimizer = torch.optim.SGD([w],lr=learning_rate)

for epoch in range(n_iters):
    # predict = forward pass
    y_pred = forward(X)

    # loss
    l = loss(Y, y_pred)

    # calculate gradients = backward pass
    l.backward()

    # update weights
    optimizer.step()
    
    # zero the gradients after updating
    optimizer.zero_grad()

    print(f'Prediction after training: f(5) = {forward(5).item():.3f}')
# Out:
# Prediction before training: f(5) = 0.000
# Prediction after training: f(5) = 1.500
# Prediction after training: f(5) = 2.775
# Prediction after training: f(5) = 3.859
# Prediction after training: f(5) = 4.780
# Prediction after training: f(5) = 5.563
# Prediction after training: f(5) = 6.229
# Prediction after training: f(5) = 6.794
# Prediction after training: f(5) = 7.275
# Prediction after training: f(5) = 7.684
# Prediction after training: f(5) = 8.031
# Prediction after training: f(5) = 8.327
# Prediction after training: f(5) = 8.578
# Prediction after training: f(5) = 8.791
# Prediction after training: f(5) = 8.972
# Prediction after training: f(5) = 9.126
# Prediction after training: f(5) = 9.257
# Prediction after training: f(5) = 9.369
# Prediction after training: f(5) = 9.464
# Prediction after training: f(5) = 9.544
# Prediction after training: f(5) = 9.612
# Prediction after training: f(5) = 9.671
# Prediction after training: f(5) = 9.720
# Prediction after training: f(5) = 9.762
# Prediction after training: f(5) = 9.798
# Prediction after training: f(5) = 9.828
# Prediction after training: f(5) = 9.854
# Prediction after training: f(5) = 9.876
# Prediction after training: f(5) = 9.894
# Prediction after training: f(5) = 9.910
# Prediction after training: f(5) = 9.924
# Prediction after training: f(5) = 9.935
# Prediction after training: f(5) = 9.945
# Prediction after training: f(5) = 9.953
# Prediction after training: f(5) = 9.960
# Prediction after training: f(5) = 9.966
# Prediction after training: f(5) = 9.971
# Prediction after training: f(5) = 9.976
# Prediction after training: f(5) = 9.979
# Prediction after training: f(5) = 9.982
# Prediction after training: f(5) = 9.985
# Prediction after training: f(5) = 9.987
# Prediction after training: f(5) = 9.989
# Prediction after training: f(5) = 9.991
# Prediction after training: f(5) = 9.992
# Prediction after training: f(5) = 9.993
# Prediction after training: f(5) = 9.994
# Prediction after training: f(5) = 9.995
# Prediction after training: f(5) = 9.996
# Prediction after training: f(5) = 9.997
# Prediction after training: f(5) = 9.997
# Prediction after training: f(5) = 9.997
# Prediction after training: f(5) = 9.998
# Prediction after training: f(5) = 9.998
# Prediction after training: f(5) = 9.998
# Prediction after training: f(5) = 9.999
# Prediction after training: f(5) = 9.999
# Prediction after training: f(5) = 9.999
# Prediction after training: f(5) = 9.999
# Prediction after training: f(5) = 9.999
# Prediction after training: f(5) = 9.999
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
# Prediction after training: f(5) = 10.000

# %%
# Design the model
# Make the loss and optimizr
# Training loop
# - forward pass : predict
# - backward pass : the loss with change its gradients
# - update weights : with the gradients of the loss funtion the optimizer will change its parameters (models)

# %%
import torch
import torch.nn as nn
# Here we replace the manually computed gradient with autograd

# Linear regression
# f = w * x 

# here : f = 2 * x
X = torch.tensor([[1], [2], [3], [4]], dtype=torch.float32)
Y = torch.tensor([[2], [4], [6], [8]], dtype=torch.float32)
X_test = torch.tensor([5],dtype=torch.float32)
n_samples,n_features = X.shape
input_size = n_features
output_size = n_features

class LinearRegreession(nn.Module):
    def __init__(self,input_size,output_size):
        super().__init__()
        # define layers
        self.lin = nn.Linear(input_size,output_size)
        
    def forward(self,x):
        return self.lin(x)

model = LinearRegreession(input_size,output_size)
    
print(f'Prediction before training: f(5) = {model(X_test).item():.3f}')

# Training
learning_rate = 0.1
n_iters = 250
loss = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)

for epoch in range(n_iters):
    # predict = forward pass
    y_pred = model(X)

    # loss
    l = loss(Y, y_pred)

    # calculate gradients = backward pass
    l.backward()

    # update weights
    optimizer.step()
    
    # zero the gradients after updating
    optimizer.zero_grad()
    
    [w,b] = model.parameters()

    print(f'Prediction while training: f(5) = {model(X_test).item():.3f}')
print(f'Prediction after training: f(5) = {model(X_test).item():.3f}')
# Out:
# Prediction before training: f(5) = 2.731
# Prediction while training: f(5) = 14.347
# Prediction while training: f(5) = 6.580
# Prediction while training: f(5) = 11.800
# Prediction while training: f(5) = 8.317
# Prediction while training: f(5) = 10.665
# Prediction while training: f(5) = 9.105
# Prediction while training: f(5) = 10.164
# Prediction while training: f(5) = 9.467
# Prediction while training: f(5) = 9.947
# Prediction while training: f(5) = 9.638
# Prediction while training: f(5) = 9.857
# Prediction while training: f(5) = 9.722
# Prediction while training: f(5) = 9.823
# Prediction while training: f(5) = 9.766
# Prediction while training: f(5) = 9.815
# Prediction while training: f(5) = 9.792
# Prediction while training: f(5) = 9.817
# Prediction while training: f(5) = 9.810
# Prediction while training: f(5) = 9.824
# Prediction while training: f(5) = 9.824
# Prediction while training: f(5) = 9.833
# Prediction while training: f(5) = 9.836
# Prediction while training: f(5) = 9.842
# Prediction while training: f(5) = 9.846
# Prediction while training: f(5) = 9.851
# Prediction while training: f(5) = 9.855
# Prediction while training: f(5) = 9.860
# Prediction while training: f(5) = 9.864
# Prediction while training: f(5) = 9.868
# Prediction while training: f(5) = 9.872
# Prediction while training: f(5) = 9.876
# Prediction while training: f(5) = 9.879
# Prediction while training: f(5) = 9.883
# Prediction while training: f(5) = 9.887
# Prediction while training: f(5) = 9.890
# Prediction while training: f(5) = 9.893
# Prediction while training: f(5) = 9.896
# Prediction while training: f(5) = 9.900
# Prediction while training: f(5) = 9.903
# Prediction while training: f(5) = 9.905
# Prediction while training: f(5) = 9.908
# Prediction while training: f(5) = 9.911
# Prediction while training: f(5) = 9.914
# Prediction while training: f(5) = 9.916
# Prediction while training: f(5) = 9.919
# Prediction while training: f(5) = 9.921
# Prediction while training: f(5) = 9.924
# Prediction while training: f(5) = 9.926
# Prediction while training: f(5) = 9.928
# Prediction while training: f(5) = 9.930
# Prediction while training: f(5) = 9.932
# Prediction while training: f(5) = 9.934
# Prediction while training: f(5) = 9.936
# Prediction while training: f(5) = 9.938
# Prediction while training: f(5) = 9.940
# Prediction while training: f(5) = 9.942
# Prediction while training: f(5) = 9.944
# Prediction while training: f(5) = 9.945
# Prediction while training: f(5) = 9.947
# Prediction while training: f(5) = 9.949
# Prediction while training: f(5) = 9.950
# Prediction while training: f(5) = 9.952
# Prediction while training: f(5) = 9.953
# Prediction while training: f(5) = 9.954
# Prediction while training: f(5) = 9.956
# Prediction while training: f(5) = 9.957
# Prediction while training: f(5) = 9.958
# Prediction while training: f(5) = 9.960
# Prediction while training: f(5) = 9.961
# Prediction while training: f(5) = 9.962
# Prediction while training: f(5) = 9.963
# Prediction while training: f(5) = 9.964
# Prediction while training: f(5) = 9.965
# Prediction while training: f(5) = 9.966
# Prediction while training: f(5) = 9.967
# Prediction while training: f(5) = 9.968
# Prediction while training: f(5) = 9.969
# Prediction while training: f(5) = 9.970
# Prediction while training: f(5) = 9.971
# Prediction while training: f(5) = 9.972
# Prediction while training: f(5) = 9.973
# Prediction while training: f(5) = 9.974
# Prediction while training: f(5) = 9.974
# Prediction while training: f(5) = 9.975
# Prediction while training: f(5) = 9.976
# Prediction while training: f(5) = 9.977
# Prediction while training: f(5) = 9.977
# Prediction while training: f(5) = 9.978
# Prediction while training: f(5) = 9.979
# Prediction while training: f(5) = 9.979
# Prediction while training: f(5) = 9.980
# Prediction while training: f(5) = 9.981
# Prediction while training: f(5) = 9.981
# Prediction while training: f(5) = 9.982
# Prediction while training: f(5) = 9.982
# Prediction while training: f(5) = 9.983
# Prediction while training: f(5) = 9.983
# Prediction while training: f(5) = 9.984
# Prediction while training: f(5) = 9.984
# Prediction while training: f(5) = 9.985
# Prediction while training: f(5) = 9.985
# Prediction while training: f(5) = 9.986
# Prediction while training: f(5) = 9.986
# Prediction while training: f(5) = 9.986
# Prediction while training: f(5) = 9.987
# Prediction while training: f(5) = 9.987
# Prediction while training: f(5) = 9.988
# Prediction while training: f(5) = 9.988
# Prediction while training: f(5) = 9.988
# Prediction while training: f(5) = 9.989
# Prediction while training: f(5) = 9.989
# Prediction while training: f(5) = 9.989
# Prediction while training: f(5) = 9.990
# Prediction while training: f(5) = 9.990
# Prediction while training: f(5) = 9.990
# Prediction while training: f(5) = 9.991
# Prediction while training: f(5) = 9.991
# Prediction while training: f(5) = 9.991
# Prediction while training: f(5) = 9.991
# Prediction while training: f(5) = 9.992
# Prediction while training: f(5) = 9.992
# Prediction while training: f(5) = 9.992
# Prediction while training: f(5) = 9.992
# Prediction while training: f(5) = 9.993
# Prediction while training: f(5) = 9.993
# Prediction while training: f(5) = 9.993
# Prediction while training: f(5) = 9.993
# Prediction while training: f(5) = 9.993
# Prediction while training: f(5) = 9.994
# Prediction while training: f(5) = 9.994
# Prediction while training: f(5) = 9.994
# Prediction while training: f(5) = 9.994
# Prediction while training: f(5) = 9.994
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.995
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.996
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.997
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.998
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 9.999
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction while training: f(5) = 10.000
# Prediction after training: f(5) = 10.000
